# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.features.build_features import (
    create_time_features,
    create_lag_features,
    create_rolling_features,
    clean_missing_values
)

# %%
df = pd.read_csv("../data/raw/Walmart.csv")

# %%
df = create_time_features(df)

# %%
df = df.sort_values(
    ["Store", "Date"]
).reset_index(drop=True)

# %%
df = create_lag_features(df)

df = create_rolling_features(df)

df = clean_missing_values(df)

# %%
df.to_csv("../data/processed/featured_data.csv", index=False)

# %%
df.head(10)
# Out:
#     Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 4       1 2010-03-05    1554806.68             0        46.50       2.625
# 5       1 2010-03-12    1439541.59             0        57.79       2.667
# 6       1 2010-03-19    1472515.79             0        54.58       2.720
# 7       1 2010-03-26    1404429.92             0        51.45       2.732
# 8       1 2010-04-02    1594968.28             0        62.27       2.719
# 9       1 2010-04-09    1545418.53             0        65.86       2.770
# 10      1 2010-04-16    1466058.28             0        66.32       2.808
# 11      1 2010-04-23    1391256.12             0        64.84       2.795
# 12      1 2010-04-30    1425100.71             0        67.41       2.780
# 13      1 2010-05-07    1603955.12             0        72.55       2.835
#
#            CPI  Unemployment  Year  Month  Week       Lag_1       Lag_2  \
# 4   211.350143         8.106  2010      3     9  1409727.59  1611968.17
# 5   211.380643         8.106  2010      3    10  1554806.68  1409727.59
# 6   211.215635         8.106  2010      3    11  1439541.59  1554806.68
# 7   211.018042         8.106  2010      3    12  1472515.79  1439541.59
# 8   210.820450         7.808  2010      4    13  1404429.92  1472515.79
# 9   210.622857         7.808  2010      4    14  1594968.28  1404429.92
# 10  210.488700         7.808  2010      4    15  1545418.53  1594968.28
# 11  210.439123         7.808  2010      4    16  1466058.28  1545418.53
# 12  210.389546         7.808  2010      4    17  1391256.12  1466058.28
# 13  210.339968         7.808  2010      5    18  1425100.71  1391256.12
#
#          Lag_4  Rolling_Mean_4  Rolling_Std_4
# 4   1643690.90    1.554615e+06  103135.002548
# 5   1641957.44    1.504011e+06   95360.050839
# 6   1611968.17    1.469148e+06   62599.457150
# 7   1409727.59    1.467823e+06   64308.381016
# 8   1554806.68    1.477864e+06   82871.762296
# 9   1439541.59    1.504333e+06   83458.043354
# 10  1472515.79    1.502719e+06   84336.491036
# 11  1404429.92    1.499425e+06   89550.298266
# 12  1594968.28    1.456958e+06   66432.182023
# 13  1545418.53    1.471593e+06   93391.490071
